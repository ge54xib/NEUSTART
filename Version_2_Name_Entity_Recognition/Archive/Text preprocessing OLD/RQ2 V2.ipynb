# %%
# Cell 7: Network Visualization and Analysis
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from itertools import combinations
import pandas as pd

# Load data
df = pd.read_csv("entities_ready_for_network.csv")

# Initialize Graph
G = nx.Graph()

# --- A. Build Edges (Co-occurrence in Block) ---
# Group by Document and Block (Paragraph level co-occurrence)
grouped = df.groupby(['Doc_ID', 'Block_ID'])['Label'].apply(list)

edge_list = []
for actors in grouped:
    # We need at least 2 actors to form a link
    if len(actors) > 1:
        # Sort to ensure (A,B) is same as (B,A)
        for u, v in combinations(sorted(actors), 2):
            edge_list.append((u, v))

# Add edges with weights (frequency of co-occurrence)
for u, v in edge_list:
    if G.has_edge(u, v):
        G[u][v]['weight'] += 1
    else:
        G.add_edge(u, v, weight=1)

# Add Node Attributes (Category)
# Create a mapping of Label -> Category
cat_map = df.set_index('Label')['qh_category'].to_dict()
nx.set_node_attributes(G, cat_map, name="category")

print(f"Network Built: {G.number_of_nodes()} Nodes, {G.number_of_edges()} Edges")

# --- B. Calculate Centrality (Emphasis) ---
degree_cent = nx.degree_centrality(G)
betweenness_cent = nx.betweenness_centrality(G)

# Create a DataFrame for Analysis
ranking = pd.DataFrame({
    'Actor': list(G.nodes()),
    'Category': [G.nodes[n]['category'] for n in G.nodes()],
    'Degree_Centrality': [degree_cent[n] for n in G.nodes()],
    'Betweenness_Centrality': [betweenness_cent[n] for n in G.nodes()]
}).sort_values(by='Degree_Centrality', ascending=False)

print("\nTop 10 Most Central Actors (Hubs):")
print(ranking.head(10))
ranking.to_csv("rq2_network_stats.csv", index=False)

# --- C. Visualization (Static) ---
plt.figure(figsize=(12, 12))

# Layout algorithm (Spring usually works best for social networks)
pos = nx.spring_layout(G, k=0.15, iterations=20, seed=42)

# Color mapping for categories
categories = list(set(cat_map.values()))
colors = plt.cm.rainbow(np.linspace(0, 1, len(categories)))
color_map = {cat: col for cat, col in zip(categories, colors)}
node_colors = [color_map.get(G.nodes[n]['category'], 'grey') for n in G.nodes()]

# Draw
nx.draw_networkx_nodes(G, pos, node_size=[v * 3000 for v in degree_cent.values()], node_color=node_colors, alpha=0.8)
nx.draw_networkx_edges(G, pos, alpha=0.3, edge_color='lightgrey')
nx.draw_networkx_labels(G, pos, font_size=8, font_color='black')

# Legend
from matplotlib.lines import Line2D
legend_elements = [Line2D([0], [0], marker='o', color='w', label=cat,
                          markerfacecolor=col, markersize=10) for cat, col in color_map.items()]
plt.legend(handles=legend_elements, loc='upper right')

plt.title("Innovation Actor Co-occurrence Network")
plt.axis('off')
plt.show()
# Out:
# Network Built: 154 Nodes, 4046 Edges
#
# Top 10 Most Central Actors (Hubs):
#                                                 Actor       Category  \
# 9                    Canada Foundation for Innovation     Government
# 21                              Global Affairs Canada     Government
# 4                 Business Development Bank of Canada     Government
# 83  Innovation, Science and Economic Development C...     Government
# 68                                             D-Wave       Industry
# 67                           Creative Destruction Lab  Civil Society
# 70                                               DRDC     Government
# 71            Defence Research and Development Canada     Government
# 72                     Department of National Defence     Government
# 69                                                DND     Government
#
#     Degree_Centrality  Betweenness_Centrality
# 9            0.764706                0.235681
# 21           0.764706                0.235681
# 4            0.575163                0.319917
# 83           0.418301                0.038184
# 68           0.398693                0.000000
# 67           0.398693                0.000000
# 70           0.398693                0.000000
# 71           0.398693                0.000000
# 72           0.398693                0.000000
# 69           0.398693                0.000000

# %%
import pandas as pd
import itertools
import networkx as nx
import matplotlib.pyplot as plt
import re

# --- 1. CONFIGURATION ---
TARGETS = ["Civil Society", "Government", "Industry", "Academia"]

# Files (Ensure these match your actual filenames)
text_csv = "output.csv"       # The file with 'Paragraph_ID' and 'text'
entities_csv = "2entities_to_edit.csv"    # The file with 'qh_category' (manual or auto)

# --- 2. LOAD & PREPARE DATA ---
print("Loading data...")
df_text = pd.read_csv(text_csv).fillna("")
df_ent = pd.read_csv(entities_csv).fillna("")

# Filter for the 4 Helix Categories
df_ent['qh_category'] = df_ent['qh_category'].astype(str).str.strip()
df_ent = df_ent[df_ent['qh_category'].isin(TARGETS)]

# Optimize: Create a dictionary mapping Doc_ID -> List of (Entity Name, Category)
# This restricts our search scope to only entities that actually belong to the document.
print("Building entity lookup map...")
doc_entity_map = {}

for doc_id, group in df_ent.groupby('Doc_ID'):
    # Store unique entities for this doc
    # We sort by length (descending) so if we wanted to prevent partial matches we could,
    # but here we just store them.
    entities = list(zip(group['entity_name'].astype(str), group['qh_category']))
    doc_entity_map[doc_id] = entities

# --- 3. BUILD NETWORK ---
G = nx.Graph()
G.add_nodes_from(TARGETS)

print(f"Scanning {len(df_text)} paragraphs. This may take a moment...")

for _, row in df_text.iterrows():
    doc_id = row['Doc_ID']
    text = str(row['text'])
    
    # Skip empty text
    if not text.strip(): continue

    # Retrieve potential entities for this document
    potential_entities = doc_entity_map.get(doc_id, [])
    
    if not potential_entities:
        continue

    # Find ALL occurrences of entities in this paragraph (including duplicates)
    found_categories = []
    
    for name, category in potential_entities:
        # Regex search: Case-insensitive
        # re.escape handles special characters in names (like "D-Wave")
        matches = re.findall(re.escape(name), text, re.IGNORECASE)
        
        # If "Government" appears 3 times, we add 'Government' 3 times to the list
        if matches:
            found_categories.extend([category] * len(matches))

    # If fewer than 2 entities found, no interaction possible
    if len(found_categories) < 2:
        continue

    # Generate Interactions (Clique)
    # We create links between EVERY combination found.
    # If found_categories = [Gov, Gov, Ind], we get pairs: (Gov, Gov), (Gov, Ind), (Gov, Ind)
    # We filter out self-loops (c1 != c2) unless you specifically want them.
    for c1, c2 in itertools.combinations(sorted(found_categories), 2):
        if c1 != c2:  # Only count cross-category interactions
            if G.has_edge(c1, c2):
                G[c1][c2]['weight'] += 1
            else:
                G.add_edge(c1, c2, weight=1)

# --- 4. VISUALIZE ---
plt.figure(figsize=(10, 8))
pos = nx.circular_layout(G)

edges = G.edges(data=True)
weights = [data['weight'] for u, v, data in edges]
max_weight = max(weights) if weights else 1

# Draw
nx.draw_networkx_nodes(G, pos, node_size=5000, node_color='#87CEFA', edgecolors='black')
nx.draw_networkx_edges(G, pos, width=[(w / max_weight) * 15 for w in weights], alpha=0.6, edge_color='gray')
nx.draw_networkx_labels(G, pos, font_size=12, font_weight='bold')

# Edge Labels
edge_labels = {(u, v): d['weight'] for u, v, d in edges}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=10)

plt.title("Quadruple Helix Network\n(Paragraph Search + Duplicates)", fontsize=15)
plt.axis('off')
plt.tight_layout()

plt.savefig("qh_network_search_duplicates.png")
plt.show()

print("✅ Graph generated with duplicate weighting!")
# Out:
# Loading data...
# Building entity lookup map...
# Scanning 528 paragraphs. This may take a moment...
# ✅ Graph generated with duplicate weighting!

# %%
import pandas as pd
import itertools
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np

# --- 1. CONFIGURATION ---
TARGETS = ["Civil Society", "Government", "Industry", "Academia"]

# Using the files generated in previous steps
text_csv = "paragraphs_master.csv"       
entities_csv = "2entities_filled.csv"    

# --- 2. LOAD & PREPARE DATA ---
print("Loading data...")
df_text = pd.read_csv(text_csv).fillna("")
df_ent = pd.read_csv(entities_csv).fillna("")

# Filter for the 4 Helix Categories
df_ent['qh_category'] = df_ent['qh_category'].astype(str).str.strip()
df_ent = df_ent[df_ent['qh_category'].isin(TARGETS)]

# Build Entity Lookup Map (Doc_ID -> List of (Name, Category))
print("Building entity lookup map...")
doc_entity_map = {}
for doc_id, group in df_ent.groupby('Doc_ID'):
    entities = list(zip(group['entity_name'].astype(str), group['qh_category']))
    doc_entity_map[doc_id] = entities

# --- 3. BUILD NETWORK ---
G = nx.Graph()
G.add_nodes_from(TARGETS)

print(f"Scanning {len(df_text)} paragraphs. This may take a moment...")

for _, row in df_text.iterrows():
    doc_id = row['Doc_ID']
    text = str(row['text'])
    
    if not text.strip(): continue

    potential_entities = doc_entity_map.get(doc_id, [])
    if not potential_entities: continue

    # Find ALL occurrences of entities (including duplicates)
    found_categories = []
    
    for name, category in potential_entities:
        # Regex search: Case-insensitive
        matches = re.findall(re.escape(name), text, re.IGNORECASE)
        if matches:
            found_categories.extend([category] * len(matches))

    # Need at least 2 entities (even of the same type) to create an interaction
    if len(found_categories) < 2:
        continue

    # Generate Interactions (Clique)
    # We create links between EVERY combination found.
    # If found_categories = [Gov, Gov, Ind]:
    #   1. (Gov, Gov) -> Self-loop (Added!)
    #   2. (Gov, Ind) -> Interaction
    #   3. (Gov, Ind) -> Interaction
    for c1, c2 in itertools.combinations(sorted(found_categories), 2):
        # REMOVED: if c1 != c2: check. Self-loops are now allowed.
        if G.has_edge(c1, c2):
            G[c1][c2]['weight'] += 1
        else:
            G.add_edge(c1, c2, weight=1)

# --- 4. GENERATE MATRICES ---
print("\nGenerating Interaction Matrix...")

# Adjacency Matrix
matrix_df = nx.to_pandas_adjacency(G, nodelist=TARGETS, weight='weight', dtype=int)

# Save Matrix
output_matrix = "qh_interaction_matrix_with_selfloops.csv"
matrix_df.to_csv(output_matrix)

print(f"Matrix saved to {output_matrix}")
print(matrix_df)

# --- 5. VISUALIZATION ---

# Plot 1: Heatmap (Best way to see self-loops on the diagonal)
plt.figure(figsize=(8, 6))
sns.heatmap(matrix_df, annot=True, fmt='d', cmap="Blues", linewidths=.5)
plt.title("Quadruple Helix Interaction Matrix (Includes Self-Loops)")
plt.tight_layout()
plt.savefig("qh_matrix_heatmap_selfloops.png")
plt.show()

# Plot 2: Network Graph
# Note: Self-loops in networkx circular_layout are often drawn as small loops on the node.
plt.figure(figsize=(10, 8))
pos = nx.circular_layout(G)
edges = G.edges(data=True)
weights = [data['weight'] for u, v, data in edges]
max_weight = max(weights) if weights else 1

# Draw Nodes
nx.draw_networkx_nodes(G, pos, node_size=5000, node_color='#87CEFA', edgecolors='black')

# Draw Edges
nx.draw_networkx_edges(G, pos, width=[(w / max_weight) * 15 for w in weights], alpha=0.6, edge_color='gray')

# Draw Labels
nx.draw_networkx_labels(G, pos, font_size=12, font_weight='bold')
edge_labels = {(u, v): d['weight'] for u, v, d in edges}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=10)

plt.title("Quadruple Helix Network (With Self-Loops)", fontsize=15)
plt.axis('off')
plt.tight_layout()
plt.savefig("qh_network_graph_selfloops.png")
plt.show()

print("✅ Analysis Complete!")
# Out:
# Loading data...
# Building entity lookup map...
# Scanning 528 paragraphs. This may take a moment...
#
# Generating Interaction Matrix...
# Matrix saved to qh_interaction_matrix_with_selfloops.csv
#                Civil Society  Government  Industry  Academia
# Civil Society             18         182        12        60
# Government               182        1490       175       454
# Industry                  12         175        17        42
# Academia                  60         454        42        63
# ✅ Analysis Complete!

# %%
import pandas as pd
import re

# Files
text_csv = "output.csv"
entities_csv = "2entities_to_edit.csv"  # or "entities_to_edit.csv"

# Load Data
df_text = pd.read_csv(text_csv).fillna("")
df_ent = pd.read_csv(entities_csv).fillna("")

# Normalize Categories
df_ent['qh_category'] = df_ent['qh_category'].astype(str).str.strip()

# Build Lookup Map (Doc_ID -> List of Entities)
doc_entity_map = {}
for doc_id, group in df_ent.groupby('Doc_ID'):
    entities = list(zip(group['entity_name'].astype(str), group['qh_category']))
    doc_entity_map[doc_id] = entities

print("Searching for 'Civil Society' x 'Government' interactions...")
print("-" * 60)

count = 0
for _, row in df_text.iterrows():
    doc_id = row['Doc_ID']
    text = str(row['text'])
    
    # Get entities for this doc
    potential_entities = doc_entity_map.get(doc_id, [])
    
    # Find Categories present in this paragraph
    found_cats = set()
    found_entities = []
    
    for name, cat in potential_entities:
        if re.search(re.escape(name), text, re.IGNORECASE):
            found_cats.add(cat)
            found_entities.append(f"{name} ({cat})")
            
    # Check for Interaction
    if "Civil Society" in found_cats and "Government" in found_cats:
        count += 1
        print(f"\n[Match #{count}]")
        print(f"Document: {row['Document_Name']} (Doc {doc_id})")
        print(f"Paragraph ID: {row['Paragraph_ID']}")
        print(f"Entities Found: {', '.join(found_entities)}")
        print(f"Text Snippet: {text[:200]}...") # First 200 chars
        print("-" * 60)

if count == 0:
    print("No interactions found.")
# Out:
# Searching for 'Civil Society' x 'Government' interactions...
# ------------------------------------------------------------
#
# [Match #1]
# Document: Canada's National Quantum Strategy (Doc 1)
# Paragraph ID: 67
# Entities Found: NQS (not an actor), Government of Canada (Government), CFI (Government), ISC (not an actor), QEYSSat (not an actor), IQC (Academia), University of Waterloo (Academia), Perimeter Institute (Academia), Canada First Research Excellence Fund (not an actor), CFREF (not an actor), Canadian Space Agency (Government), Natural Sciences and Engineering Research Council of Canada (Government), NSERC (Government), MiQro Innovation Collaborative Center (Civil Society), C2MI (Civil Society), Quantum Algorithms Institute (Civil Society), NSERC Alliance (not an actor), Institute for Quantum Computing (Academia), Perimeter (Academia), The Government of Canada (Government), CED (Government), REGI (not an actor), Council (not specified), Invest (Government)
# Text Snippet: Research: Developing better solutions  Continuing to support Canada’s research base is essential to ensure leadership in quantum science and technology. Basic and applied research to better understand...
# ------------------------------------------------------------
#
# [Match #2]
# Document: Canada's National Quantum Strategy (Doc 1)
# Paragraph ID: 71
# Entities Found: NQS (not an actor), Government of Canada (Government), SIF (not an actor), ISC (not an actor), NSERC (Government), Université de Sherbrooke (Academia), Institute for Quantum Computing (Academia), Institut Quantique (Academia), Stewart Blusson Quantum Matter Institute (Academia), Mitacs (Civil Society), NSERC CREATE (not an actor), Mitacs Accelerate International (not an actor), The Government of Canada (Government), CED (Government), Invest (Government)
# Text Snippet: Talent: Building a world-leading workforce  Developing, attracting and retaining talent are critical for Canada to succeed in quantum science and technology. The talent shortages already faced by indu...
# ------------------------------------------------------------
#
# [Match #3]
# Document: Canada's National Quantum Strategy (Doc 1)
# Paragraph ID: 73
# Entities Found: Statistics Canada (Government), Quantum Industry Canada (Civil Society), Creative Destruction Lab (Civil Society), Invest (Government)
# Text Snippet: Commercialization: Translating research into commercial outcomes  Driven by the development of new technologies that promise economic and societal benefits, many nations around the world are pursuing ...
# ------------------------------------------------------------
#
# [Match #4]
# Document: Canada's National Quantum Strategy (Doc 1)
# Paragraph ID: 77
# Entities Found: NQS (not an actor), Government of Canada (Government), Quantum Industry Canada (Civil Society), The Government of Canada (Government), Quantum Advisory Council (Government), Council (not specified), Quantum Committee (not an actor), NQS Secretariat (Government), Invest (Government)
# Text Snippet: T o achieve the objectives of the NQS, the  Government of Canada needs to establish  mechanisms to tap into thought leadership and engage representatives along the entire innovation continuum—from res...
# ------------------------------------------------------------
#
# [Match #5]
# Document: Canada's National Quantum Strategy (Doc 1)
# Paragraph ID: 78
# Entities Found: NQS (not an actor), ISC (not an actor), Perimeter Institute (Academia), Institute for Quantum Computing (Academia), Institut Quantique (Academia), Perimeter (Academia), CED (Government), Government of Quebec (Government), Sherbrooke Quantum Innovation Zone (Civil Society), Institut Quantique de Sherbrooke (Academia), IBM Quantum Hub (Industry), IBM (Industry), IBM Q System One (not an actor), Anyon Systems (Industry), Government of Ontario (Government), Perimeter Institute for Theoretical Physics (Academia), Invest (Government)
# Text Snippet: Provincial and international collaboration  M utually beneficial collaboration will be  critical to the success of the NQS,  including among domestic businesses  and researchers, within federal depart...
# ------------------------------------------------------------
#
# [Match #6]
# Document: Canada's National Quantum Strategy (Doc 1)
# Paragraph ID: 80
# Entities Found: Quantum Algorithms Institute (Civil Society), Government of British Columbia (Government)
# Text Snippet: •  In 2019, the Government of British Columbia committed $17 million over five years to establish the Quantum Algorithms Institute....
# ------------------------------------------------------------
#
# [Match #7]
# Document: Canada's National Quantum Strategy (Doc 1)
# Paragraph ID: 85
# Entities Found: NQS (not an actor), Government of Canada (Government), Mitacs (Civil Society), GAC (Government), The Government of Canada (Government), Canadian International Innovation Program (not an actor), GAC’s Trade Commissioner Service (Government), TCS (Government), Invest (Government), Trade Commissioner Service (Government)
# Text Snippet: To strengthen the talent pipeline, the Government of Canada will work with Mitacs to facilitate integrated work placements for foreign experts in Canadian industry. As well, GAC’s Trade Commissioner S...
# ------------------------------------------------------------
#
# [Match #8]
# Document: Canada's National Quantum Strategy (Doc 1)
# Paragraph ID: 107
# Entities Found: NSERC (Government), Mitacs (Civil Society), NSERC CREATE (not an actor)
# Text Snippet: Talent will be supported through programming at NSERC and Mitacs:  •  NSERC CREATE grants program ($5.4 million over six years)...
# ------------------------------------------------------------
#
# [Match #9]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 2
# Entities Found: WMI (Academia), Janine Gückelhorn (not specified), Federal Government (not specified), EU (Government), USA (not an actor), DIN (Civil Society), FI (Academia), TUM (Academia), Quantum Computers (not an actor)
# Text Snippet: WMI doctoral student Janine Gückelhorn makes preparations on an ultra-high vacuum sputtering system for the production of high-purity metal coatings. 1. Exploiting the potential of quantum technologie...
# ------------------------------------------------------------
#
# [Match #10]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 8
# Entities Found: Federal Government (not specified), USA (not an actor), NIST (Government), DIN (Civil Society), Q.ANT (Industry), FI (Academia), TUM (Academia)
# Text Snippet: A Q.ANT employee shows a wafer from which photonic chips are cut. A young woman adjusts a non-linear optical system. Central to this is the establishment of an efficient ecosystem in which all relevan...
# ------------------------------------------------------------
#
# [Match #11]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 14
# Entities Found: EU (Government), BMWK (Government), DIN (Civil Society), FI (Academia), TUM (Academia), BMW (Industry)
# Text Snippet: ∙ Develop optical clocks for the next Galileo generation and, together with European partners, driveforward the development of the next generation ofsatellite-based gravity field quantum sensors (up t...
# ------------------------------------------------------------
#
# [Match #12]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 25
# Entities Found: EU (Government), NIST (Government), DIN (Civil Society)
# Text Snippet: ∙ work towards close dovetailing with Europeanpartners at all levels. This includes cooperation ontechnological issues as well as the development ofcommon standards, including those relating to respon...
# ------------------------------------------------------------
#
# [Match #13]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 26
# Entities Found: Federal Government (not specified), EU (Government), Federal Government’s ‘Future Strategy for Research and Innovation’ (not an actor), NIST (Government), DIN (Civil Society), Annex (not specified), FI (Academia), TUM (Academia)
# Text Snippet: The quantum technologies conceptual framework programme contributes to the goals of the Federal Government’s ‘Future Strategy for Research and Innovation’. It contributes to securing the technological...
# ------------------------------------------------------------
#
# [Match #14]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 27
# Entities Found: EU (Government), DIN (Civil Society), FI (Academia), TUM (Academia), Quantum Computers (not an actor)
# Text Snippet: A young man in a laboratory adjusts the optics on a device. 2.Huge challenges, extraordinary potential Quantum technologies, i.e., the targeted control of quantum mechanical effects and their technolo...
# ------------------------------------------------------------
#
# [Match #15]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 28
# Entities Found: Federal Government (not specified), EU (Government), Google (Industry), IBM (Industry), USA (not an actor), NIST (Government), NASA (Government), DARPA (Government), European Union (Government), Federal Government’s Future Package (not an actor), DIN (Civil Society), ISO (Civil Society), FI (Academia), TUM (Academia)
# Text Snippet: involved in quantum cryptography is based on phys-ical laws of nature and not on mathematical assump-tions. A wide variety of quantum communication methods have since been demonstrated in use, both in...
# ------------------------------------------------------------
#
# [Match #16]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 30
# Entities Found: EU (Government), DIN (Civil Society)
# Text Snippet: ∙ embedding in the European internal market...
# ------------------------------------------------------------
#
# [Match #17]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 40
# Entities Found: NIST (Government), DIN (Civil Society), ISO (Civil Society)
# Text Snippet: ∙ when making an international comparison, there isless venture capital available and higher administrative hurdles regarding start-ups and their promotion...
# ------------------------------------------------------------
#
# [Match #18]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 53
# Entities Found: Federal Government (not specified), EU (Government), USA (not an actor), DIN (Civil Society), ICON (Civil Society), FI (Academia), Quantum Optics (Academia), TUM (Academia), FAU (Academia), Quantum Computers (not an actor)
# Text Snippet: This rough analysis demonstrates the great potential for Germany due to its strong base in quantum technologies. It forms the basis for the Federal Government’s measures outlined below to bring German...
# ------------------------------------------------------------
#
# [Match #19]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 54
# Entities Found: Federal Government (not specified), EU (Government), USA (not an actor), Expert Commission on Research and Innovation17 (Government), DIN (Civil Society), FI (Academia), TUM (Academia), Quantum Computers (not an actor)
# Text Snippet: A young woman and a young man are standing in a laboratory environment. They are both wearing safety goggles and are working on adjusting a device. 3.Top-level technology for creative power and techno...
# ------------------------------------------------------------
#
# [Match #20]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 59
# Entities Found: Federal Government (not specified), USA (not an actor), DIN (Civil Society), BSI (Government), FI (Academia), TUM (Academia)
# Text Snippet: The Federal Government’s measures are divided into three action pathways: A young woman looks through a microscope. A.Make quantum technologies usable for the economy, society and state institutions Q...
# ------------------------------------------------------------
#
# [Match #21]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 60
# Entities Found: EU (Government), German Aerospace Centre (Academia), DLR (Academia), DIN (Civil Society), FI (Academia), TUM (Academia), Quantum Computers (not an actor)
# Text Snippet: ∙ Through the targeted awarding of contracts formarketable products, the public sector acts as acentral anchor and reference customer for companies that develop and manufacture such hardwarein Germany...
# ------------------------------------------------------------
#
# [Match #22]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 61
# Entities Found: Federal Government (not specified), EU (Government), DeepTech & Climate Fonds (Industry), DTCF (Industry), HTGF (Industry), theDTCF (Industry), DIN (Civil Society), High-Tech Gründerfonds (Industry), FI (Academia), TUM (Academia)
# Text Snippet: ∙ The borrowing requirements of young companiesthat bring new developments to market maturitycan also be met through direct public sector participation. With the new DeepTech & Climate Fonds(DTCF) tha...
# ------------------------------------------------------------
#
# [Match #23]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 66
# Entities Found: Federal Government (not specified), EU (Government), DIN (Civil Society), FI (Academia), TUM (Academia)
# Text Snippet: The application perspective in quantum computing tends to be of a medium- to long-term nature with a possible time horizon of five to 15 years due to greater development needs (see also ‘Technology Li...
# ------------------------------------------------------------
#
# [Match #24]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 68
# Entities Found: EU (Government), FederalGovernment (not specified), DIN (Civil Society), FI (Academia), TUM (Academia)
# Text Snippet: ∙ Building on these activities, by 2032 the FederalGovernment aims to achieve quantum benefitsusing European hardware solutions in concrete use cases carried out by companies in Germany....
# ------------------------------------------------------------
#
# [Match #25]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 70
# Entities Found: Federal Government (not specified), EU (Government), DIN (Civil Society), FI (Academia), TUM (Academia), Quantum Computers (not an actor)
# Text Snippet: Societal challenges  Societies around the world are facing major challenges: Climate change is a global phenomenon. Tackling it and dealing with its consequences requires action on a common global, Eu...
# ------------------------------------------------------------
#
# [Match #26]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 86
# Entities Found: Federal Government (not specified), EU (Government), CEN-CENELEC Quantum Technology Focus Group (Civil Society), CEN-CENELEC (Civil Society), DIN (Civil Society), ISO (Civil Society), FI (Academia), TUM (Academia), Joint Technical Committee (Civil Society), Quantum Computers (not an actor)
# Text Snippet: Setting standards Issues surrounding standardisation and norms will play a crucial role in the future development, mastery and diffusion of the technology. In this way commercial enterprises can be su...
# ------------------------------------------------------------
#
# [Match #27]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 88
# Entities Found: Federal Government (not specified), EU (Government), USA (not an actor), European Union (Government), DIN (Civil Society), Q.ANT (Industry), FI (Academia), TUM (Academia), Quantum Computers (not an actor)
# Text Snippet: A Q.ANT engineer prepares a photonic chip for the next step. Technology lighthouse: quantum computing  Compared to the other branches of quantum technologies, quantum computing is expected to have the...
# ------------------------------------------------------------
#
# [Match #28]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 95
# Entities Found: Federal Government (not specified), EU (Government), USA (not an actor), DIN (Civil Society), FI (Academia), TUM (Academia)
# Text Snippet: C.Create excellent framework conditions for a strong ecosystem Create interfaces: strengthen ecosystems In order to make the new technologies application-ready and therefore usable within the economy ...
# ------------------------------------------------------------
#
# [Match #29]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 108
# Entities Found: Federal Government (not specified), NIST (Government), DIN (Civil Society), Federal Government The Federal Government (not specified), FI (Academia), TUM (Academia)
# Text Snippet: A young woman behind a gold-coloured frame in the laboratory. 4.Acting together – securing sovereignity Joint action by the Federal Government The Federal Government jointly coordinates its measures i...
# ------------------------------------------------------------
#
# [Match #30]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 110
# Entities Found: Federal Government (not specified), EU (Government), CEN-CENELEC (Civil Society), DIN (Civil Society), Horizon Europe (not an actor), Digital Europe (not an actor), QuantERA (not an actor), EU Commission (Government), ESA (Government), EuroQCI (not an actor), Federal States (not specified), FI (Academia), TUM (Academia), Quantum Computers (not an actor)
# Text Snippet: tive federal states. Close networking of the Federal Government with the specific measures and priorities of the federal states is ensured by regular coordination meetings at working level. In additio...
# ------------------------------------------------------------
#
# [Match #31]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 111
# Entities Found: EU (Government), DIN (Civil Society), ESA (Government), FI (Academia), TUM (Academia)
# Text Snippet: Specifically in terms of technological sovereignty, it is important that close coordination with European partners continues. Especially in quantum computing and quantum communication, the aim is to a...
# ------------------------------------------------------------
#
# [Match #32]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 114
# Entities Found: Federal Government (not specified), EU (Government), DLR (Academia), DIN (Civil Society), TUM (Academia)
# Text Snippet: In combination with national and European activities, it is possible to engender targeted momentum and thereby strengthen the ecosystem.  In addition to the targeted strengthening of collaborations, t...
# ------------------------------------------------------------
#
# [Match #33]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 115
# Entities Found: EU (Government), DIN (Civil Society), FI (Academia), TUM (Academia)
# Text Snippet: Production of optimised photon pair sources. 5.Milestones and resource planning The success of the conceptual framework programme is measured by milestones, which at research policy level serve as tar...
# ------------------------------------------------------------
#
# [Match #34]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 134
# Entities Found: Federal Government (not specified), EU (Government), NIST (Government), DIN (Civil Society), Annex (not specified), ISO (Civil Society), FI (Academia), TUM (Academia)
# Text Snippet: In addition, the impact of the Federal Government’s measures is tracked using overarching and topic-specific indicators; these are evaluated as part of assessments of the programmes upon which this co...
# ------------------------------------------------------------
#
# [Match #35]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 136
# Entities Found: Federal Government (not specified), EU (Government), BMBF (Government), BMI (Government), BMWK (Government), NIST (Government), DLR (Academia), DIN (Civil Society), Gauss Centre for Supercomputing (Academia), ESA (Government), Cyber Security Strategy (not an actor), Cyber Security Strategy for Germany (not an actor), Federal States (not specified), European Cybersecurity Strategy (not an actor), Cybersecurity Strategy for Germany (not an actor), Space Agency (Academia), National Programme for Space and Innovation (not an actor), Ecosystem for Quantum assisted Artificial Intelligence (Civil Society), Agentur für Innovation in der Cybersicherheit GmbH (Government), Bundesamt für Sicherheit in der Informationstechnik (Government), Federal Office for Information  Security (Government), BSI (Government), ISO (Civil Society), IEC (Civil Society), NISQ (not an actor), Thunderbird (not an actor), OpenPGP (not an actor), Internet Engineering Task Force (Civil Society), IETF (Civil Society), European Telecommunications Standards Institute (Civil Society), ETSI (Civil Society), Physikalisch-Technische Bundesanstalt (Academia), National Metrology Institute of Germany (Academia), PTB (Academia), Schirmprojekt Quantenkommunikation Deutschland (not an actor), Quantum Communication Germany (not an actor), Bundesdruckerei GmbH Bundesdruckerei GmbH (Industry), Maurer Electronics GmbH (Industry), Bundesdruckerei Group (Industry), Bundesdruckerei GmbH (Industry), Bundesdruckerei (Industry), Federal Administration (not specified), Federal Ministry of Finance (Government), ICON (Civil Society), FI (Academia), TUM (Academia), BMW (Industry), IOM (Academia), Quantum Computers (not an actor), QKD (not an actor)
# Text Snippet: BMBF Research Programme on High Performance Computing72 With this programme the BMBF is funding innovations in high-performance computing and the expansion of computing infrastructure into the exascal...
# ------------------------------------------------------------
#
# [Match #36]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 139
# Entities Found: Federal Government (not specified), EU (Government), BMI (Government), NIST (Government), Bundeswehr (Government), DIN (Civil Society), PTB (Academia), Bundesdruckerei (Industry), Federal Administration (not specified), Federal Data Atlas (not an actor), Federal AI Competence Centre (Government), DB Systel (Industry), Bundesquantenallianz (Civil Society), BQA (Civil Society), BAM (Academia), BWI GmbH BWI GmbH (Industry), BWI (Industry), Deutsche Forschungsgemeinschaft e (Government), German Research Foundation (Government), DFG (Government), Clusters of Excellence (not specified), European Research Area (not an actor), Research Training Group (not specified), Deutscher Wetterdienst (Academia), German Weather Service (Academia), DWD (Academia), FI (Academia), TUM (Academia), German Armed Forces (Government)
# Text Snippet: The project works with partners from science, industry, start-ups and administration and relies on a collaborative approach. The first partners have already been found or are within the selection proc...
# ------------------------------------------------------------
#
# [Match #37]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 140
# Entities Found: EU (Government), IBM (Industry), Bundeswehr (Government), DWD (Academia), ICON (Civil Society), Max Planck Institut für Meteorology (Academia), MPI-M (Academia), German Climate Computing Center (Academia), DKRZ (Academia), Karlsruhe Institute of Technologe (Academia), KIT (Academia), Cyber Defence and Smart Data Research Institute (Academia), FI (Academia), University of the Bundeswehr Munich The FI CODE (Academia), FI CODE (Academia), MPI (Academia), TUM (Academia), Quantum Computers (not an actor), University of the Bundeswehr Munich (Academia)
# Text Snippet: Weather and climate simulations represent a primary use case for utilising high-performance computing (HPC) infrastructures due to their computing power and storage capacity demands. With the ICON-Con...
# ------------------------------------------------------------
#
# [Match #38]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 147
# Entities Found: EU (Government), DIN (Civil Society), FI (Academia), Fraunhofer-Gesellschaft (Academia), TUM (Academia)
# Text Snippet: The Fraunhofer-Gesellschaft has been working intensively on this key emerging technology since 2016 and already provided funding for it in 2017 through the flagship QUILT project (focus on quantum ima...
# ------------------------------------------------------------
#
# [Match #39]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 150
# Entities Found: EU (Government), DIN (Civil Society), ForschungsfabrikMikroelektronik Deutschland (Academia), FMD (Academia), TUM (Academia)
# Text Snippet: ∙ Establish fabs & pilot lines for closed supply chainsin a competitive & autonomous German-Europeaneconomic area, including the ForschungsfabrikMikroelektronik Deutschland (FMD) with theQuantum and N...
# ------------------------------------------------------------
#
# [Match #40]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 151
# Entities Found: EU (Government), BMBF (Government), USA (not an actor), DIN (Civil Society), FI (Academia), Helmholtz-Gemeinschaft Deutscher Forschungszentren e (Academia), Helmholtz Association of German Research Centres (Academia), HGF (Academia), The Helmholtz Centres (Academia), Helmholtz Quantum (Academia), Helmholtz Association (Academia), Helmholtz (Academia), TUM (Academia), Quantum Computers (not an actor)
# Text Snippet: Optical components of a non-linear interferometer. Helmholtz-Gemeinschaft Deutscher Forschungszentren e. V. [Helmholtz Association of German Research Centres] (HGF) The Helmholtz Centres that contribu...
# ------------------------------------------------------------
#
# [Match #41]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 157
# Entities Found: EU (Government), DLR (Academia), DIN (Civil Society), FI (Academia), HGF (Academia), DLR Quantum Computing Initiative (Academia), Max-Planck-Gesellschaft zur Förderung der Wissenschaften e (Academia), Max Planck Society for the Advancement of Science (Academia), Max Planck Society (Academia), MPG (Academia), Max Planck Institute (Academia), MPI (Academia), Quantum Optics (Academia), MPI for Gravitational Physics (Academia), Physics of Light (Academia), Max Planck Institutes for Solid State Research in Stuttgart (Academia), Multidisciplinary Natural Sciences (Academia), Structure and Dynamics of Matter (Academia), Fritz Haber Institute (Academia), QST (not an actor), Garching (not an actor), TUM (Academia), Quantum Computers (not an actor), Solid State (not an actor)
# Text Snippet: An additional contribution by DLR outside the programme-oriented research funding of the HGF is the DLR Quantum Computing Initiative, which has been funded with around EUR 740 million from the fiscal ...
# ------------------------------------------------------------
#
# [Match #42]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 164
# Entities Found: EU (Government), BMI (Government), Google (Industry), NIST (Government), DLR (Academia), DIN (Civil Society), ESA (Government), Physikalisch-Technische Bundesanstalt (Academia), National Metrology Institute of Germany (Academia), PTB (Academia), FI (Academia), FhG (Academia), MPG (Academia), QST (not an actor), Max Planck Quantum Alliance (Academia), MPQA (Academia), MQV (Civil Society), Bavarian Academy of Sciences and Humanities (Academia), BAdW (Academia), Ludwig- Maximilians-Universität München (Academia), LMU (Academia), Tech-nische Universität München (Academia), TUM (Academia), Friedrich- Alexander-Universität Erlangen-Nürnberg (Academia), FAU (Academia), Fraunhofer Gesellschaft (Academia), German Aerospace Center (Academia), MQV Association (Civil Society), Free State of Bavaria (Government), Federal Ministry of Education and Research (Government), Quantum Technologies Stimulus Package (not an actor), Federal Ministry for Economic Affairs and Climate Action (Government), Centre for Quantum Computing and Quantum Technol-ogies (Civil Society), ZQQ (Civil Society), Airbus (Industry), BMW (Industry), Fujitsu (Industry), Huawei (Industry), Infineon (Industry), Menlo Systems (Industry), Microsoft (Industry), OHB (Industry), Rohde&Schwarz (Industry), Siemens (Industry), Toptica Photonics (Industry), Volkswagen (Industry), Federal Institute of Metrology (Government), QT (not an actor), Quantum Technology Competence Centre (Government), QTZ (Government), QTcomponents (not an actor), IOM (Academia)
# Text Snippet: The MPG sees its contribution to the national strategy primarily within the context of the continuation and expansion of excellent fundamental research. This also includes opening up new subject areas...
# ------------------------------------------------------------
#
# [Match #43]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 169
# Entities Found: EU (Government), BMBF (Government), DIN (Civil Society), BSI (Government), PTB (Academia), Quantum Communication Germany (not an actor), FI (Academia), TUM (Academia)
# Text Snippet: ∙ The recently selected future cluster (, expected to start in March 2023)complements the high-tech incubator throughcooperation with established industry figures. PTBcoordinates the BMBF-funded Quant...
# ------------------------------------------------------------
#
# [Match #44]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 170
# Entities Found: EU (Government), CEN-CENELEC (Civil Society), DIN (Civil Society), ISO (Civil Society), PTB (Academia), European Research Area (not an actor), ICON (Civil Society), FI (Academia), TUM (Academia), QT (not an actor), Joint Technical Committee (Civil Society), Leibniz Association (Academia), Ferdinand Braun Institute (Academia), Leibniz Institute for Highest Frequency Technology (Academia), FBH (Academia), Leibniz Institute for Solid State and Materials Research (Academia), IFW (Academia), Leibniz Institute for Innovative Microelectronics (Academia), IHP (Academia), Leibniz Institute for Crystal Growth (Academia), IKZ (Academia), Leibniz Institute for Surface Modification (Academia), IOM (Academia), Leibniz Institute for Photonic Technologies (Academia), IPHT (Academia), Paul Drude Institute for Solid State Electronics (Academia), PDI (Academia), Weierstrass Institute for Applied Analysis and Stochastics (Academia), WIAS (Academia), Leibniz Institutes (Academia), Leibniz (not specified), Solid State (not an actor)
# Text Snippet: An open vacuum chamber. For the industrial development of QT participation in standardisation is an important factor – standards that have been set outside Europe must not limit the compatibility of Q...
# ------------------------------------------------------------
#
# [Match #45]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 171
# Entities Found: Federal Government (not specified), NIST (Government), Bundeswehr (Government), DIN (Civil Society), ISO (Civil Society), ICON (Civil Society), FI (Academia), TUM (Academia), Leibniz Institutes (Academia), Leibniz (not specified), Research Factory Microelectronics Germany (Academia), QSolid (not an actor), Quantum Computers (not an actor), Solid State (not an actor), MU-NIQC-SC (not an actor), Munich Quantum Valley Quantum Comput-er Demonstrators (not an actor), BECCAL (not an actor), Bose-Einstein Condensate (not an actor), Cold Atom Lab (not an actor), International Space Station (not an actor), Zentrum für Digitalisierungs (Government), Technologieforschung der Bundeswehr (Government), Centre for  Digitisation and Technology Research of the  Bundeswehr (Government), German Armed Forces (Government), Fighting the Consequences of Covid (not an actor), BMVg (Government), University of the Bundeswehr Munich (Academia)
# Text Snippet: In the field of quantum computing, which is impor-tant for potential tasks in critical application fields such as chemistry, meteorology, finance and for mate-rial or drug development, the institutes ...
# ------------------------------------------------------------
#
# [Match #46]
# Document: Quantum Technologies Conceptual Framework Programme (Doc 2)
# Paragraph ID: 172
# Entities Found: EU (Government), European Union (Government), DIN (Civil Society), NISQ (not an actor), FI (Academia), TUM (Academia), Quantum Computers (not an actor), Galileo A (not an actor), American GPS (not an actor), QKD (not an actor), TRL 5 (not an actor)
# Text Snippet: 7.Glossary Defects in diamond or NV centres Impurities of a diamond lattice due to individual foreign atoms, such as nitrogen (‘nitrogen vacancy’). This forms an excited spectrum that can be used, eve...
# ------------------------------------------------------------
#
# [Match #47]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 1
# Entities Found: Department for Science, Innovation and Technology (Government), DSIT (Government), The UK (not specified), oA (not specified), National Quantum Technologies Programme (not an actor), MoD (Government), National Quantum Strategy (not an actor), Government (not specified), IET (Civil Society), NIST (Government), Quantum Technologies (not an actor), EY (Industry), MOD (Government), NSI (not an actor), UN (Government)
# Text Snippet: National Quantum Strategy  Ministerial Foreword  The first generation of quantum technologies created many innovations that we now take for granted in modern society, from the MRI machine to mobile de...
# ------------------------------------------------------------
#
# [Match #48]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 2
# Entities Found: Rt Hon Michelle Donelan (not an ORG), The UK (not specified), oA (not specified), Government (not specified), IET (Civil Society), Quantum Computing (not an actor), CAP (Academia), Quantum Technologies (not an actor), EY (Industry), NSI (not an actor), CEN (Civil Society), UN (Government)
# Text Snippet: The Rt Hon Michelle Donelan MP  Secretary of State for Science, Innovation and Technology  Executive Summary  Over the next ten years, quantum technologies will revolutionise many aspects of life in t...
# ------------------------------------------------------------
#
# [Match #49]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 14
# Entities Found: The UK (not specified), oA (not specified), National Quantum Technologies Programme (not an actor), Government (not specified), IET (Civil Society), Quantum Computing (not an actor), CAP (Academia), Quantum Technologies (not an actor), EY (Industry), NSI (not an actor), UN (Government)
# Text Snippet: Government investments to date through the National Quantum Technologies Programme have created a unique and diverse pool of talent, capabilities and know-how within our quantum sector. However, given...
# ------------------------------------------------------------
#
# [Match #50]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 18
# Entities Found: National Science and Technology Council (Government), The UK (not specified), IET (Civil Society), NIST (Government), Quantum Technologies (not an actor), EY (Industry), UN (Government)
# Text Snippet: This strategy sets out a ten-year vision, plan and priority actions. As quantum technologies develop, the UK will need to make some key strategic decisions about where to focus efforts to realise the ...
# ------------------------------------------------------------
#
# [Match #51]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 23
# Entities Found: The UK (not specified), oA (not specified), Government (not specified), Quantum Technologies (not an actor), CEN (Civil Society), UN (Government)
# Text Snippet: For details on the data-sources that underpin this table and for the methodology, please refer to the Technical Annex to be published alongside this strategy. We will be publishing a further evidence ...
# ------------------------------------------------------------
#
# [Match #52]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 36
# Entities Found: Quantum Computing Centre (Academia), National Quantum Computing Centre (Academia), Quantum Computing (not an actor), CEN (Civil Society), UN (Government)
# Text Snippet: o£20 million additional funding for increased activities through theNational Quantum Computing Centre...
# ------------------------------------------------------------
#
# [Match #53]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 38
# Entities Found: Doctoral Training (Academia), Quantum Skills Taskforce (not specified), CEN (Civil Society), UN (Government)
# Text Snippet: 3 Recognising the importance of skilled people, launch new doctoral training centres and fellowships in quantum, a Quantum Skills Taskforce, and develop an industry placement scheme and a quantum appr...
# ------------------------------------------------------------
#
# [Match #54]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 43
# Entities Found: The UK (not specified), Quantum Computing Centre (Academia), National Quantum Computing Centre (Academia), Government (not specified), Quantum Computing (not an actor), Quantum Technologies (not an actor), EY (Industry), Catalyst Fund (not specified), CEN (Civil Society), UN (Government)
# Text Snippet: 8 Establish stronger mechanisms and catalyst funding through a quantum catalyst fund to accelerate government procurement and enable government to act as an intelligent, early customer of quantum tech...
# ------------------------------------------------------------
#
# [Match #55]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 48
# Entities Found: oA (not specified), National Quantum Technologies Programme (not an actor), Strategic Advisory Board (not an actor), Peter Knight (not an actor), Institute of Physics (not an actor), Institution of Engineering and Technology (not an actor), Royal Academy of Engineering (not an actor), UKQuantum (not an actor), Quantum Technologies (not an actor), ITU (Government), ISO (Civil Society)
# Text Snippet: We have consulted widely during the work on this strategy and would like to thank all those who contributed to our call for evidence and participated in workshops and discussions. We are particularly ...
# ------------------------------------------------------------
#
# [Match #56]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 49
# Entities Found: The UK (not specified), oA (not specified), National Quantum Technologies Programme (not an actor), Artur Ekert (not an ORG), National Quantum Technologies Programme  The UK (not an actor), NQTP (not an actor), Quantum Research Hubs (Academia), theEngineering and Physical Sciences Research Council (Government), EPSRC (Government), MoD (Government), Government (not specified), IET (Civil Society), CAP (Academia), Quantum Technologies (not an actor), EY (Industry), MOD (Government), Defence (not specified), NSI (not an actor), UN (Government)
# Text Snippet: Introduction: Quantum Technologies in the UK  What are quantum technologies?  Many technologies that are part of our everyday life are based on our knowledge of quantum mechanics, from the lasers that...
# ------------------------------------------------------------
#
# [Match #57]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 51
# Entities Found: The UK (not specified), Quantum Computing Centre (Academia), National Quantum Computing Centre (Academia), NQCC (Academia), UKRI (Government), Quantum Computing (not an actor), ITU (Government), CEN (Civil Society), UN (Government)
# Text Snippet: •£93 million in the National Quantum Computing Centre (NQCC), a newresearch institution funded through UKRI, that is driving activities to build ascalable quantum computer in the UK;10...
# ------------------------------------------------------------
#
# [Match #58]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 56
# Entities Found: The UK (not specified), Quantum Computing Centre (Academia), Commission (not specified), National Quantum Computing Centre (Academia), NQCC (Academia), UKRI (Government), National Physical Laboratory (Government), NPL (Government), STFC (Government), Fraunhofer Centre for Applied Photonics (Academia), Universities of York (Academia), Government (not specified), Quantum Computing (not an actor), CAP (Academia), Fraunhofer (Academia), EY (Industry), ITU (Government), NSI (not an actor), CEN (Civil Society), UN (Government)
# Text Snippet: The National Quantum Computing Centre (NQCC)  The National Quantum Computing Centre (NQCC) is a new research institution funded through UKRI, which is dedicated to accelerating the development of quan...
# ------------------------------------------------------------
#
# [Match #59]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 57
# Entities Found: The UK (not specified), EPSRC (Government), Dstl (Government), UK National Quantum Hub in Sensors and Timing and Defence Science and Technology Laboratory (Academia), RSK (Industry), Teledyne e2V (Industry), UK Commercialising Quantum Challenge (not an actor), Defence Science and Technology Laboratory (Government), PhD (not an actor), Quantum Computing (not an actor), CAP (Academia), Quantum Technologies (not an actor), EY (Industry), Defence (not specified), NSI (not an actor), ISO (Civil Society), CEN (Civil Society), UN (Government)
# Text Snippet: Quantum Sensors and Timing  Despite our increasing ability to detect and monitor things that exist on land, sea or in space, we still often resort to digging or drilling holes to find objects such as ...
# ------------------------------------------------------------
#
# [Match #60]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 61
# Entities Found: The UK (not specified), European Union19 (not an actor), Government (not specified), ITU (Government), CEN (Civil Society), UN (Government)
# Text Snippet: •Global investment and competition are increasing at a rapid pace and scale. The UK isworking within a changing geopolitical context with other governments ramping upinvestment into their national res...
# ------------------------------------------------------------
#
# [Match #61]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 63
# Entities Found: National Science and Technology Council (Government), The UK (not specified), oA (not specified), Government (not specified), PNT (not an actor), IET (Civil Society), NIST (Government), Quantum Computing (not an actor), CAP (Academia), Quantum Technologies (not an actor), EY (Industry), NSI (not an actor), UN (Government)
# Text Snippet: Our Approach  The UK is in a strong position to play a world-leading role in quantum technologies, if we can overcome the challenges outlined above (many of which are shared by other nations). We have...
# ------------------------------------------------------------
#
# [Match #62]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 68
# Entities Found: The UK (not specified), oA (not specified), UKRI (Government), Government (not specified), Thehubs (not specified), IET (Civil Society), CAP (Academia), Quantum Technologies (not an actor), EY (Industry), CEN (Civil Society), UN (Government)
# Text Snippet: Goal 1: World-leading research and skills  We will ensure the UK is home to world-leading quantum science and engineering, growing UK knowledge and skills  Research and Development  The UK is the home...
# ------------------------------------------------------------
#
# [Match #63]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 73
# Entities Found: Quantum Computing Centre (Academia), National Physical Laboratory (Government), NationalQuantum Computing Centre (Academia), Quantum Computing (not an actor), CEN (Civil Society), UN (Government)
# Text Snippet: •Infrastructure investments: to meet the needs of the evolving field and sector, includingcontinued funding for core operational activities of national facilities such as the NationalQuantum Computing...
# ------------------------------------------------------------
#
# [Match #64]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 76
# Entities Found: oA (not specified), PNT (not an actor), IET (Civil Society), Quantum Computing (not an actor), EY (Industry), UN (Government)
# Text Snippet: •£70 million in the development of two short-term quantum missions focussed onachieving key technological milestones around quantum computing and PNT. Thisapproach over the next three years will act a...
# ------------------------------------------------------------
#
# [Match #65]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 79
# Entities Found: CEN (Civil Society), UN (Government)
# Text Snippet: •£20 million for acceleration activities, working with the sector on collaborative R&D inquantum networking.•£20 million additional funding for increased activities through the National QuantumComputi...
# ------------------------------------------------------------
#
# [Match #66]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 82
# Entities Found: The UK (not specified), IET (Civil Society), Quantum Computing (not an actor), EY (Industry), CEN (Civil Society), UN (Government)
# Text Snippet: For this investment of £2.5 billion we are expecting the private sector to commit to invest £1 billion into the programme over its lifetime. Up to now, we have achieved evenly matched industry funding...
# ------------------------------------------------------------
#
# [Match #67]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 84
# Entities Found: The UK (not specified), EPSRC (Government), NQCC (Academia), UKRI (Government), National Physical Laboratory (Government), Centres for Doctoral Training (Academia), CDTs (Academia), Dstl (Government), STFC (Government), Government (not specified), Doctoral Training (Academia), Defence Science and Technology Laboratory (Government), 26  Fellowships  Quantum (not specified), Joint EPSRC (not an actor), UKRI Future Leaders Fellowship (not an actor), STFC Ernest Rutherford Fellowships (not an actor), Defence (not specified), CEN (Civil Society), UN (Government)
# Text Snippet: People and know-how are driving the early development of the emerging sector. We have provided strong support for growing the highly-specialised skills needed in the quantum sector since 2014. We have...
# ------------------------------------------------------------
#
# [Match #68]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 85
# Entities Found: The UK (not specified), UKRI (Government), Government (not specified), Royal Society (Academia), IET (Civil Society), UK Innovation Strategy (not an actor), EY (Industry), UN (Government)
# Text Snippet: Visa routes  The government is updating the routes that talented individuals in the field of quantum can use to come to the UK and continue their careers. We will ensure that the quantum sector is abl...
# ------------------------------------------------------------
#
# [Match #69]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 86
# Entities Found: The UK (not specified), Institute of Physics (not an actor), NPL (Government), Doctoral Training (Academia), Institution of Engineering & Technology (Civil Society), IET (Civil Society), IoP (Civil Society), Quantum Technologies (not an actor), EY (Industry), ITU (Government), NSI (not an actor), CEN (Civil Society), UN (Government)
# Text Snippet: Building a quantum-literate workforce  As the sector scales, there will be a need for more emphasis on routes into the sector beyond doctoral training, as well as to build the pipeline from schools up...
# ------------------------------------------------------------
#
# [Match #70]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 87
# ...
# ------------------------------------------------------------
#
# [Match #82]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 125
# Entities Found: The UK (not specified), oA (not specified), Government (not specified), Quantum Computing (not an actor), PsiQuantum (Industry), IBM (Industry), Hartree National Centre for Digital Innovation (Academia), Department for Business and Trade (Government), CEN (Civil Society), UN (Government)
# Text Snippet: Attracting quantum businesses to the UK  Much of the UK quantum business sector is formed from homegrown talent, nurtured through our universities and quantum hubs or established in larger UK companie...
# ------------------------------------------------------------
#
# [Match #83]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 126
# Entities Found: The UK (not specified), oA (not specified), IET (Civil Society), Quantum Computing (not an actor), Quantum Technologies (not an actor), EY (Industry), CEN (Civil Society), UN (Government)
# Text Snippet: Goal 3: Driving the adoption of Quantum Technologies in the UK  Drive the adoption of quantum technologies in the UK to deliver benefits for the economy, society and for national security  If the UK i...
# ------------------------------------------------------------
#
# [Match #84]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 127
# Entities Found: The UK (not specified), oA (not specified), NQCC (Academia), Government (not specified), PNT (not an actor), IET (Civil Society), CAP (Academia), EY (Industry), Catalyst Fund (not specified), CEN (Civil Society), UN (Government)
# Text Snippet: We will raise awareness of the opportunities and foster the right connections to build an understanding of user needs. We will set direction and providing a signal of intent by focussing efforts on wh...
# ------------------------------------------------------------
#
# [Match #85]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 129
# Entities Found: The UK (not specified), oA (not specified), NQCC (Academia), MoD (Government), PNT (not an actor), Quantum Computing (not an actor), CAP (Academia), Quantum Technologies (not an actor), EY (Industry), Future of Compute (not an actor), MOD (Government), Defence (not specified), ITU (Government), NSI (not an actor), CEN (Civil Society), UN (Government)
# Text Snippet: An environmentally sustainable and resilient UK: By mimicking nature a quantum computer could simulate new materials, accelerate improvements in solar panels and batteries, and help improve the effici...
# ------------------------------------------------------------
#
# [Match #86]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 130
# Entities Found: The UK (not specified), oA (not specified), Quantum Computing Centre (Academia), National Quantum Computing Centre (Academia), NQCC (Academia), Government (not specified), IET (Civil Society), Quantum Computing (not an actor), EY (Industry), Quantum Software Laboratory (Academia), University of Edinburgh (Academia), Oxford Quantum Circuits (Industry), OQC (Industry), SparQ (not an actor), ITU (Government), NSI (not an actor), CEN (Civil Society), UN (Government)
# Text Snippet: NQCC test bed for quantum computing applications  The NQCC has developed an extensive programme of support for users under the SparQ Applications Discovery Programme, to help them understand the oppor...
# ------------------------------------------------------------
#
# [Match #87]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 131
# Entities Found: The UK (not specified), NQTP (not an actor), MoD (Government), Government (not specified), Quantum Computing (not an actor), CAP (Academia), National Security Strategic Investment Fund (Government), NSSIF (Government), Quantum Technologies (not an actor), EY (Industry), Small Business Research Initiative (not an actor), SBRI (not an actor), MOD (Government), MOD Science & Technology Strategy (not an actor), Defence (not specified), NSI (not an actor), CEN (Civil Society), UN (Government)
# Text Snippet: Leading by example through government signalling and procurement  There are many areas where quantum technologies could improve public service delivery and enhance government’s capabilities – from imp...
# ------------------------------------------------------------
#
# [Match #88]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 132
# Entities Found: NQCC (Academia), Government (not specified), EY (Industry), SparQ (not an actor), Defence (not specified), CEN (Civil Society), UN (Government)
# Text Snippet: •Accelerate the recently launched NQCC SparQ Applications Discovery programme, withspecific workstreams dedicated to use case exploration, testing, and upskilling withinthe public, defence, aerospace,...
# ------------------------------------------------------------
#
# [Match #89]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 133
# Entities Found: NQCC (Academia), IET (Civil Society), Crick Institute (Academia), Faraday Institution (Academia), ITU (Government), CEN (Civil Society), UN (Government)
# Text Snippet: •Dedicate at least a quarter of the NQCC’s access to computing platforms andassociated research programmes towards exploring critical applications of societalbenefit, such as realising the advantages ...
# ------------------------------------------------------------
#
# [Match #90]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 134
# Entities Found: PNT (not an actor), IET (Civil Society), CAP (Academia), Quantum Technologies (not an actor), EY (Industry), UN (Government)
# Text Snippet: •Deliver missions focussed on achieving societal benefits and commercial value, startingwith two missions (accelerating quantum technologies for resilient capabilities inPosition Navigation & Timing (...
# ------------------------------------------------------------
#
# [Match #91]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 144
# Entities Found: The UK (not specified), oA (not specified), IET (Civil Society), World Economic Forum (Industry), Quantum Computing (not an actor), Quantum Technologies (not an actor), EY (Industry), World Economic Forum Global Future Council (Industry), WEF Global Future Councils (Industry), NSI (not an actor), UN (Government)
# Text Snippet: There is an important opportunity for the UK to be at the forefront of quantum regulation and lead the way in trialling quantum technologies.  We also have a key role to play in leading the internatio...
# ------------------------------------------------------------
#
# [Match #92]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 149
# Entities Found: The UK (not specified), Government (not specified), IET (Civil Society), CAP (Academia), NSI (not an actor), UN (Government)
# Text Snippet: Protecting the UK sector to support growth  Whilst the government has an objective to support the growth of the quantum sector which is anticipated to lead to many benefits for society, the economy an...
# ------------------------------------------------------------
#
# [Match #93]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 152
# Entities Found: The UK (not specified), Commission (not specified), MoD (Government), Framework (not an actor), Government (not specified), IET (Civil Society), NIST (Government), Quantum Computing (not an actor), NPSA (Government), National Cyber Security Centre (Government), NCSC (Government), Quantum Technologies (not an actor), EY (Industry), MOD (Government), ITU (Government), NSI (not an actor), Trusted Research (not an actor), Academic Technology Approval Scheme (not an actor), ATAS (not an actor), ACMT (not an actor), National Security and Investment Act (not an actor), NSIA (not an actor), ECJU (Government), Wassenaar Arrangement (Government), International Organization for Standardization (Civil Society), ISO (Civil Society), International Electrotechnical Commission (Civil Society), IEC (Civil Society), International Telecommunication Union (Government), Internet Engineering Task Force (Civil Society), IETF (Civil Society), European Telecommunications Standards Institute (Civil Society), ETSI (Civil Society), Institute of Electrical and Electronics Engineers (Civil Society), IEEE (Civil Society), BSI (Government), CEN (Civil Society), UN (Government)
# Text Snippet: Key regulatory frameworks  Government guidance for academia (“Trusted Research”) and industry ( “Secure Innovation”), as well as wider advice1 is available through NPSA and NCSC. They seek to support ...
# ------------------------------------------------------------
#
# [Match #94]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 153
# Entities Found: oA (not specified), MoD (Government), EY (Industry), MOD (Government), ITU (Government), British Standards Institute (Civil Society), National PhysicalLaboratory and MOD (Government)
# Text Snippet: •Work with key partners (e.g. the British Standards Institute, the National PhysicalLaboratory and MOD) to scope and identify the best approach to coordinating nationalengagement in priority areas of ...
# ------------------------------------------------------------
#
# [Match #95]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 154
# Entities Found: DSIT (Government), oA (not specified), Commission (not specified), National Quantum Technologies Programme (not an actor), NQCC (Academia), National Physical Laboratory (Government), NPL (Government), MoD (Government), Framework (not an actor), Government (not specified), NIST (Government), ISCF (not an actor), Quantum Computing (not an actor), NCSC (Government), Quantum Technologies (not an actor), EY (Industry), MOD (Government), ITU (Government), NSI (not an actor), ISO (Civil Society), IEC (Civil Society), British Standards Institute (Civil Society), International Standards Development Organisations (not specified), SDOs (not specified), National Institute of Standards and Technology (Government), BSI (Government), CENELEC (Civil Society), CEN (Civil Society), CENELEC Focus Group (Civil Society), FGQT (Civil Society), UN (Government)
# Text Snippet: Existing UK governance of quantum technical standards  Quantum computing, quantum communications, quantum imaging and quantum sensors and timing are at different stages of standardisation activity and...
# ------------------------------------------------------------
#
# [Match #96]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 155
# Entities Found: DSIT (Government), The UK (not specified), oA (not specified), Office for Quantum (Government), National Quantum Technologies Programme (not an actor), Quantum Metrology Institute (Government), National Physical Laboratory (Government), NPL (Government), Government (not specified), IET (Civil Society), Quantum Computing (not an actor), CAP (Academia), Quantum Technologies (not an actor), ITU (Government), National Physical Laboratory  The Quantum Metrology Institute (Government), QMI (Government), Advanced Quantum Metrology Laboratory (Academia), AQML (Academia), NPL Teddington (Government), UN (Government)
# Text Snippet: The Quantum Metrology Institute at the National Physical Laboratory  The Quantum Metrology Institute (QMI) at NPL was established in 2015 as part of the first phase of the National Quantum Technologie...
# ------------------------------------------------------------
#
# [Match #97]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 159
# Entities Found: oA (not specified), Strategic Advisory Board (not an actor), Government (not specified), ISO (Civil Society), theQuantum Strategic Advisory Board (Government)
# Text Snippet: •Broaden and deepen the current independent advisory structures to enable them toadvise the government on strategy implementation. The remit and membership of theQuantum Strategic Advisory Board will ...
# ------------------------------------------------------------
#
# [Match #98]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 160
# Entities Found: The UK (not specified), Institute of Physics (not an actor), Royal Academy of Engineering (not an actor), UKQuantum (not an actor), Institute of Engineering and Technology (Civil Society), EY (Industry), ITU (Government), theRoyal Academy of Engineering (Civil Society), Institute of Engineering and Technology andTechUK (Civil Society), UN (Government)
# Text Snippet: •Work closely with UKQuantum, as representatives of the UK quantum industries sector,and other key industry and professional bodies such as the Institute of Physics, theRoyal Academy of Engineering, t...
# ------------------------------------------------------------
#
# [Match #99]
# Document: National Quantum Strategy (Doc 3)
# Paragraph ID: 161
# Entities Found: The UK (not specified), oA (not specified), Quantum Computing Centre (Academia), Commission (not specified), National Quantum Computing Centre (Academia), Institute of Physics (not an actor), Royal Academy of Engineering (not an actor), UKQuantum (not an actor), Quantum Research Hubs (Academia), NQCC (Academia), National Physical Laboratory (Government), NPL (Government), Centres for Doctoral Training (Academia), MoD (Government), Framework (not an actor), Government (not specified), PNT (not an actor), Doctoral Training (Academia), Institution of Engineering & Technology (Civil Society), IET (Civil Society), IoP (Civil Society), PhD (not an actor), Quantum Skills Taskforce (not specified), STEM Learning (Academia), OECD (Government), World Economic Forum (Industry), G7 (Government), NATO (Government), Quantum Computing (not an actor), CAP (Academia), Department for Business and Trade (Government), Quantum Technologies (not an actor), EY (Industry), Catalyst Fund (not specified), SparQ (not an actor), MOD (Government), Defence (not specified), Crick Institute (Academia), Faraday Institution (Academia), World Trade Organisation (Government), G20 (Government), Council of Europe (Government), Commonwealth (Government), International Telecommunications Union (Government), ITU (Government), Regulatory Horizons Council (Government), NSI (not an actor), ISO (Civil Society), British Standards Institute (Civil Society), CEN (Civil Society), UK Research and Innovation (Government), National Quantum Research Hubs (not specified), UK International Tech Strategy (not an actor), International Science Partnerships Fund    Demonstrate UK (not an actor), Government User Group (not specified), UN (Government)
# Text Snippet: Summary of Actions  Vision: For the UK to be a world leading quantum-enabled economy by 2033, building on scientific excellence and a thriving quantum sector to ensure that quantum technologies are an...
# ------------------------------------------------------------
#
# [Match #100]
# Document: NATIONAL STRATEGIC  OVERVIEW FOR QUANTUM  INFORMATION SCIENCE (Doc 4)
# Paragraph ID: 20
# Entities Found: U.S. Quantum Consortium (Civil Society), Government (not specified), NSF (Government), EAR (not specified)
# Text Snippet: Deepening engagement with quantum industry    Foster the formation of a U.S. Quantum Consortium with participants from industry, academia, and Government to forecast and establish consensus on needs ...
# ------------------------------------------------------------
#
# [Match #101]
# Document: NATIONAL STRATEGIC  OVERVIEW FOR QUANTUM  INFORMATION SCIENCE (Doc 4)
# Paragraph ID: 39
# Entities Found: QIS (not an actor), NSTC (Government), Nation (not specified), U.S. Quantum Consortium (Civil Society), Government (not specified), STEM (not specified), Semiconductor Research Corporation (Academia), Council of Advisors on Science and Technology (Government), EAR (not specified), OMB (not specified)
# Text Snippet: 6 Deepening engagement with quantum industry  The revolutionary advances expected to come from QIS have already led to substantial industry attention on QIS research and development. Both large compan...
# ------------------------------------------------------------

# %%
# Install pyvis if you haven't (run this in your terminal/notebook)
# %pip install pyvis

import pandas as pd
import itertools
import networkx as nx
import re
import numpy as np
from pyvis.network import Network

# --- 1. CONFIGURATION ---
TARGETS = ["Civil Society", "Government", "Industry", "Academia"]
# Hex colors for PyVis
HELIX_COLORS = {
    "Civil Society": "#4ECDC4", 
    "Government": "#45B7D1", 
    "Industry": "#FF6B6B", 
    "Academia": "#96CEB4"
}

text_csv = "paragraphs_master.csv"       
entities_csv = "2entities_filled.csv"    

# --- 2. LOAD & PREPARE DATA ---
print("Loading data...")
df_text = pd.read_csv(text_csv).fillna("")
df_ent = pd.read_csv(entities_csv).fillna("")

df_ent['qh_category'] = df_ent['qh_category'].astype(str).str.strip()
df_ent = df_ent[df_ent['qh_category'].isin(TARGETS)]

doc_entity_map = {}
for doc_id, group in df_ent.groupby('Doc_ID'):
    entities = list(zip(group['entity_name'].astype(str), group['qh_category']))
    doc_entity_map[doc_id] = entities

# --- 3. BUILD NETWORK ---
G = nx.Graph()
G.add_nodes_from(TARGETS)

print("Scanning paragraphs...")
for _, row in df_text.iterrows():
    doc_id = row['Doc_ID']
    text = str(row['text'])
    if not text.strip(): continue

    potential_entities = doc_entity_map.get(doc_id, [])
    if not potential_entities: continue

    found_categories = []
    for name, category in potential_entities:
        matches = re.findall(re.escape(name), text, re.IGNORECASE)
        if matches:
            found_categories.extend([category] * len(matches))

    if len(found_categories) < 2: continue

    for c1, c2 in itertools.combinations(sorted(found_categories), 2):
        if G.has_edge(c1, c2):
            G[c1][c2]['weight'] += 1
        else:
            G.add_edge(c1, c2, weight=1)

# --- 4. PYVIS VISUALIZATION ---
print("Generating Interactive Graph...")

# Create PyVis Network
nt = Network(height="750px", width="100%", bgcolor="#222222", font_color="white", notebook=False)

# Add Nodes with Custom Styling
# Calculate total weight for sizing
degrees = dict(G.degree(weight='weight'))
max_degree = max(degrees.values()) if degrees else 1

for node in TARGETS:
    # Size node by total interactions (degree)
    size = 20 + (degrees.get(node, 0) / max_degree * 50)
    
    nt.add_node(
        node, 
        label=node, 
        color=HELIX_COLORS[node],
        size=size,
        title=f"Total Interactions: {degrees.get(node, 0)}", # Tooltip
        font={'size': 20, 'face': 'arial'}
    )

# Add Edges
for u, v, data in G.edges(data=True):
    weight = data['weight']
    # Scale width
    width = (weight / max_degree) * 10
    if width < 1: width = 1
    
    nt.add_edge(
        u, v, 
        value=weight, 
        width=width,
        title=f"{u} - {v}: {weight} interactions", # Tooltip
        color='#ffffff' # White edges for dark background
    )

# Physics Options for a nice layout
nt.force_atlas_2based()
nt.show_buttons(filter_=['physics']) # Allow user to play with physics settings

output_html = "qh_interactive_network.html"
nt.write_html(output_html)

print(f"✅ Interactive graph saved to: {output_html}")
# You would open this HTML file in Chrome/Firefox
# Out:
# Requirement already satisfied: pyvis in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from pyvis) (9.8.0)
# Requirement already satisfied: jinja2>=2.9.6 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from pyvis) (3.1.6)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from pyvis) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from pyvis) (3.6.1)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from ipython>=5.3.0->pyvis) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from jedi>=0.18.1->ipython>=5.3.0->pyvis) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from jinja2>=2.9.6->pyvis) (3.0.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->pyvis) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->pyvis) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\user\onedrive - tum\master thesis\analysis\neustart\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->pyvis) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Loading data...
# Scanning paragraphs...
# Generating Interactive Graph...
# ✅ Interactive graph saved to: qh_interactive_network.html
